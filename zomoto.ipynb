# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
zomato = pd.read_csv('C:/Users/HP/Downloads/Zomto/zomato.csv')

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.shape
# Out:
# (51717, 17)

# %%
zomato.info
# Out:
# <bound method DataFrame.info of                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.index
# Out:
# RangeIndex(start=0, stop=51717, step=1)

# %%
zomato.iloc

# %%
zomato.loc

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
zomato.shape
# Out:
# (51717, 17)

# %%
zomato.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
zomato["cuisines"].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ...,
#        'North Indian, Street Food, Biryani', 'Chinese, Mughlai',
#        'North Indian, Chinese, Arabian, Momos'], dtype=object)

# %%
zomato.nunique()
# Out:
# url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              64
# votes                           2328
# phone                          14926
# location                          93
# rest_type                         93
# dish_liked                      5271
# cuisines                        2723
# approx_cost(for two people)       70
# reviews_list                   22513
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %%
zomato["dish_liked"].unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
zomato.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
zomato["cuisines"].value_counts()
# Out:
# North Indian                                   2913
# North Indian, Chinese                          2385
# South Indian                                   1828
# Biryani                                         918
# Bakery, Desserts                                911
#                                                ...
# North Indian, Chinese, South Indian, Juices       1
# North Indian, Chinese, Kebab, Mughlai             1
# Chinese, Vietnamese, Thai, Malaysian              1
# Arabian, Lebanese, Chinese, Rolls                 1
# North Indian, Chinese, Arabian, Momos             1
# Name: cuisines, Length: 2723, dtype: int64

# %%
zomato.head(30)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 6   https://www.zomato.com/bangalore/rosewood-inte...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# ...

# %%
zomato.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
sns.heatmap(zomato.isnull())
# Out:
# <AxesSubplot:>

# %%
zomato.dropna(axis = 0, inplace =True)

# %%
sns.heatmap(zomato.isnull())
# Out:
# <AxesSubplot:>

# %%
zomato.tail()
# Out:
#                                                      url  \
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# ...

# %%
zomato.tail()
# Out:
#                                                      url  \
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# ...

# %%
zomato.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
zomato["votes"] = zomato["votes"].astype("int")

# %%
zomato["online_order"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23193 entries, 0 to 51715
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int32
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
# ...

# %%
zomato.loc[10, 'menu_item']
# Out:
# '[]'

# %%
zomato.loc[100, 'cuisines']
# Out:
# 'South Indian'

# %%
zomato.head(10)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
#
#                                               address  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1   2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 3   1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4   10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...

# %%
zomato.iloc[[100,200],[6,3]]
# Out:
#      votes online_order
# 207   2339          Yes
# 412    128          Yes

# %%
zomato.iloc[[50,200],[3,6]]
# Out:
#     online_order  votes
# 76           Yes    558
# 412          Yes    128

# %%
zomato.fillna('votes')
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.sort_values('votes', ascending=False)
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
# 4944   https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# ...                                                  ...
# 30496  https://www.zomato.com/bangalore/cheers-pub-ba...
# 13421  https://www.zomato.com/bangalore/empire-restau...
# 24899  https://www.zomato.com/bangalore/kaapikada-1-k...
# 10944  https://www.zomato.com/bangalore/baba-chatkora...
# 21773  https://www.zomato.com/bangalore/fusion-theory...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 50059         Behind MK Retail, Sarjapur Road, Bangalore
# 49627         Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
zomato.value_counts('votes', ascending=False)
# Out:
# votes
# 0       151
# 61      140
# 53      136
# 46      126
# 48      115
#        ...
# 2341      1
# 2342      1
# 2347      1
# 2350      1
# 2308      1
# Length: 2283, dtype: int64

# %%
zomato.nlargest(10,"votes")
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
# 4944   https://www.zomato.com/bangalore/byg-brewski-b...
# 18643  https://www.zomato.com/bangalore/toit-indirana...
# 19268  https://www.zomato.com/bangalore/toit-indirana...
# 36668  https://www.zomato.com/bangalore/truffles-kora...
# 33913  https://www.zomato.com/bangalore/truffles-kora...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 49627         Behind MK Retail, Sarjapur Road, Bangalore
# 50059         Behind MK Retail, Sarjapur Road, Bangalore
# 3921          Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
zomato.nsmallest(10,"votes")
# Out:
#                                                     url  \
# 1011  https://www.zomato.com/bangalore/le-arabia-jp-...
# 2239  https://www.zomato.com/bangalore/brahma-brews-...
# 2240  https://www.zomato.com/bangalore/levitate-brew...
# 2250  https://www.zomato.com/bangalore/le-arabia-jp-...
# 2258  https://www.zomato.com/bangalore/nourich-jp-na...
# 2462  https://www.zomato.com/bangalore/levitate-brew...
# 2463  https://www.zomato.com/bangalore/brahma-brews-...
# 2481  https://www.zomato.com/bangalore/fusion-theory...
# 2780  https://www.zomato.com/bangalore/thyme-whisk-j...
# 3224  https://www.zomato.com/bangalore/thyme-whisk-j...
#
#                                                 address  \
# 1011    15, Bannerghatta Main Road, JP Nagar, Bangalore
# 2239  24th Main, 7th Phase, Opposite Brigade Palm Sp...
# 2240  57, 1st Main Rd, Sarakki Industrial Layout, 3r...
# 2250    15, Bannerghatta Main Road, JP Nagar, Bangalore
# 2258  67, Ground Floor, 3rd E Main Road, 15th Cross ...
# ...

# %%
zomato.copy
# Out:
# <bound method NDFrame.copy of                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.where
# Out:
# <bound method DataFrame.where of                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
from scipy import stats

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
sns.heatmap(zomato.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
zomato["location"].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Jayanagar', 'Kumaraswamy Layout',
#        'Rajarajeshwari Nagar', 'Mysore Road', 'Uttarahalli',
#        'South Bangalore', 'Vijay Nagar', 'Bannerghatta Road', 'JP Nagar',
#        'BTM', 'Wilson Garden', 'Koramangala 5th Block', 'Shanti Nagar',
#        'Richmond Road', 'City Market', 'Bellandur', 'Sarjapur Road',
#        'Marathahalli', 'HSR', 'Old Airport Road', 'Indiranagar',
#        'Koramangala 1st Block', 'East Bangalore', 'MG Road',
#        'Brigade Road', 'Lavelle Road', 'Church Street', 'Ulsoor',
#        'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road', 'Domlur',
#        'Koramangala 8th Block', 'Frazer Town', 'Ejipura', 'Vasanth Nagar',
#        'Jeevan Bhima Nagar', 'Old Madras Road', 'Commercial Street',
#        'Koramangala 6th Block', 'Majestic', 'Langford Town',
#        'Koramangala 7th Block', 'Brookefield', 'Whitefield',
# ...

# %%
zomato["approx_cost(for two people)"]
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51705    1,200
# 51707    2,000
# 51708    1,200
# 51711      800
# 51715    2,500
# Name: approx_cost(for two people), Length: 23193, dtype: object

# %%
zomato["approx_cost(for two people)"] = zomato["approx_cost(for two people)"].astype(str)

# %%
zomato["approx_cost(for two people)"]
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51705    1,200
# 51707    2,000
# 51708    1,200
# 51711      800
# 51715    2,500
# Name: approx_cost(for two people), Length: 23193, dtype: object

# %%
zomato.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
zomato['name'].describe()
# Out:
# count      23193
# unique      3159
# top       Onesta
# freq          85
# Name: name, dtype: object

# %%
zomato.groupby(['dish_liked','menu_item'])

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato['online_order'].describe()
# Out:
# count     23193
# unique        2
# top         Yes
# freq      16358
# Name: online_order, dtype: object

# %%
plt.figure(figsize=(16,10))
sns.countplot(x=zomato['location'])
plt.title('Number of Restaurants in a Location')
plt.xticks(rotation=90);

# %%
top_locations=zomato.location.value_counts(ascending=False).head(10)
sns.barplot(x=top_locations.index, y=top_locations.values)
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Location with maximum number of Restaurants')
plt.xlabel('Location')
plt.ylabel('Number of Restaurants');

# %%
zomato.rate.value_counts(ascending=False).head()
# Out:
# 3.9/5     1689
# 3.9 /5    1549
# 4.0/5     1469
# 4.1/5     1398
# 4.0 /5    1391
# Name: rate, dtype: int64

# %%
zomato.groupby('name')['votes'].max().sort_values(ascending=False).head(10)
# Out:
# name
# Byg Brewski Brewing Company    16832
# Toit                           14956
# Truffles                       14726
# AB's - Absolute Barbecues      12121
# The Black Pearl                10550
# Big Pitcher                     9300
# Onesta                          9085
# Arbor Brewing Company           8419
# Empire Restaurant               8304
# Prost Brew Pub                  7871
# Name: votes, dtype: int32

# %%
top_votes= zomato.groupby('name')['votes'].max().sort_values(ascending=False).head(10)
sns.barplot(x=top_votes.index, y=top_votes.values,palette="cubehelix")
plt.xticks(rotation=45,ha='right')
plt.title('Restaurants with maximum votes')
plt.xlabel('Restaurants')
plt.ylabel('Number of Votes')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
zomato["online_order"].value_counts().plot(kind="pie", autopct="%1.1f%%", 
wedgeprops=dict(width=.3, edgecolor='w'))
plt.title('Percentage of restaurants that offer online order');

# %%
top_votes= zomato.groupby('name')['votes'].max().sort_values(ascending=False).head(10)
sns.barplot(x=top_votes.index, y=top_votes.values,palette="cubehelix")
plt.xticks(rotation=45,ha='right')
plt.title('Restaurants with maximum votes')
plt.xlabel('Restaurants')
plt.ylabel('Number of Votes')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
sns.barplot(x=top_votes.index, y=top_votes.values,palette="cubehelix")
plt.xticks(rotation=45,ha='right')
plt.title('Restaurants with maximum votes')
plt.xlabel('Restaurants')
plt.ylabel('Number of Votes')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
zomato["online_order"].value_counts().plot(kind="pie", autopct="%1.1f%%", wedgeprops=dict(width=.3, edgecolor='w'))
plt.title('Percentage of restaurants that offer online order');

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato.drop(columns=['url','address','reviews_list'], inplace=True)

# %%
zomato.shape
# Out:
# (23193, 14)

# %%
top_types=zomato.rest_type.value_counts(ascending=False).head(10)
plt.figure(figsize=(10,7))
sns.barplot(x=top_types.values, y=top_types.index,palette='mako')
plt.title('Top 10 Restaurant types');

# %%
top_rest=Zomato.name.value_counts(ascending=False).head(10)
plt.figure(figsize=(8,5))
sns.barplot(x=top_rest.values, y=top_rest.index,palette="viridis",)
plt.title('Top 10 Chains of Restaurants in Bangalore');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 top_rest=Zomato.name.value_counts(ascending=False).head(10)
#       2 plt.figure(figsize=(8,5))
#       3 sns.barplot(x=top_rest.values, y=top_rest.index,palette="viridis",)
#
# NameError: name 'Zomato' is not defined

# %%
cuisines=Zomato["cuisines"].value_counts(ascending=False).head(10)
sns.barplot(y=cuisines.index, x=cuisines.values,palette="viridis")
plt.title('Most Preferred cuisines in Restaurants');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 cuisines=Zomato["cuisines"].value_counts(ascending=False).head(10)
#       2 sns.barplot(y=cuisines.index, x=cuisines.values,palette="viridis")
#       3 plt.title('Most Preferred cuisines in Restaurants');
#
# NameError: name 'Zomato' is not defined

# %%
Zomato["book_table"].value_counts().plot(kind="pie", autopct="%1.1f%%", wedgeprops=dict(width=.3, edgecolor='w'))
plt.title('Percentage of restaurants that offer online table booking');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 Zomato["book_table"].value_counts().plot(kind="pie", autopct="%1.1f%%", wedgeprops=dict(width=.3, edgecolor='w'))
#       2 plt.title('Percentage of restaurants that offer online table booking');
#
# NameError: name 'Zomato' is not defined

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=zomato['Vote'], y=zomato['approx_cost(for two people)'])
plt.title('Rating with table booking')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.ipython\profile_default\pid\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.ipython\profile_default\pid\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.ipython\profile_default\pid\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vote'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
top_exp=zomato.groupby('name')['approx_cost(for two people)'].max().sort_values(ascending= False).head(10)
plt.figure(figsize=(10,7))
sns.barplot(y=top_exp.index, x=top_exp.values,palette="rocket")
plt.title('Top 10 Expensive Restaurants')
plt.xlabel('Restaurants')
plt.ylabel('approx_cost(for two people'));
# Out:
#   Cell In[87], line 6
#     plt.ylabel('approx_cost(for two people'));
#                                             ^
# SyntaxError: unmatched ')'

# %%
top_types=zomato.rest_type.value_counts(ascending=False).head(10)
plt.figure(figsize=(10,7))
sns.barplot(x=top_types.values, y=top_types.index,palette='mako')
plt.title('Top 10 Restaurant types');

# %%
zomato.head(1)
# Out:
#     name online_order book_table   rate  votes  \
# 0  Jalsa          Yes        Yes  4.1/5    775
#
#                             phone      location      rest_type  \
# 0  080 42297555\r\n+91 9743772233  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                          cuisines approx_cost(for two people) menu_item  \
# 0  North Indian, Mughlai, Chinese                         800        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 cuisines=data["cuisines"].value_counts(ascending=False).head(10)
#       2 sns.barplot(y=cuisines.index, x=cuisines.values,palette="viridis")
#       3 plt.title('Most Preferred cuisines in Restaurants');
#
# NameError: name 'data' is not defined

# %%
Analysis Report
Most common service type of restaurants is Delivery followed by Dine-out.
Most common type of meal restaurant in Bangalore is Quick Bites and Casual Dining.
Top Location that have maximum number of restaurant is BTM followed by HR and Koramangala 5th Block
Around 12277 restaurants have rating higher or equal to 4 and 38786 restaurants have rating less than 4
Some of the Highest rated restaurants include Belgian Waffle Factory, Byg Brewski Brewing Company and some others.
Top Restaurant with maximum number of voting are Byg Brewski Brewing Company followed by Toit and Truffles.
Around 59.2% restaurants offer online ordering.
Mojarity of the restaurants that is 87.4% does'nt offer online table booking.
Most expensive restaurant in Bangalore is Le Cirque Signature - The Leela Palace that cost around 6000 for two people.
It predicts from the dataset that retaurants with low-cost are likely to get maximum rating
Majority of the restaurants get highest rating that offer online table booking.
Restaurants get highest rating that offer online ordering system.
Most Chains of Restaurant in Bangalore is Cafe Coffee Day and Onesta.
